# %% [markdown]
# - **Kelas** : IF403
# - **Program Studi** : PJJ Informatika
# - **Nama Mahasiswa** : Raka Anggie Saputra
# - **NIM** : 240401010148

# %%
# SEL 1: Output sederhana
print ("Hello, Data Science!")

#SEL 2: Variabel & tipe data
nama = "Raka Anggie Saputra"
prodi = "PJJ Informatika"
angkatan = 2024
print(f"Halo, {nama} mahasiswa {prodi} angkatan {angkatan}!")

#SEL 3: List & perulangan
tools = ["Python", "Colab", "Jupyter", "Github"]
for i, tool in enumerate(tools, 1):
  print(f"  {i}. {tool}")

# SEL 4: Fungsi python
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Raka", "Informatika", 2024))
# Out:
# Hello, Data Science!
# Halo, Raka Anggie Saputra mahasiswa PJJ Informatika angkatan 2024!
#   1. Python
#   2. Colab
#   3. Jupyter
#   4. Github
# Raka | Informatika | 2024

# %% [markdown]
# # Deskripsi Notebook - Pertemuan 1
#
# ## Rangkuman Isi Notebook
#
# Notebook ini memuat latihan dasar Python yang terbagi menjadi empat komponen utama dalam satu sel eksekusi:
#
# 1. **Output Dasar & Percetakan Teks**
#    * Menampilkan teks statis `"Hello, Data Science!"` menggunakan fungsi `print()`.
#
# 2. **Manajemen Variabel & Tipe Data**
#    * Pendeklarasian variabel bertipe data String (`nama`, `prodi`) dan Integer (`angkatan`).
#    * Penerapan f-string (formatted string literals) untuk menggabungkan variabel ke dalam teks output secara dinamis.
#
# 3. **Struktur Data List & Perulangan (Looping)**
#    * Pembuatan komponen list (`tools`) yang menampung beberapa perkakas data science (Python, Colab, Jupyter, GitHub).
#    * Pemanfaatan perulangan `for` yang dikombinasikan dengan fungsi `enumerate()` untuk menghasilkan daftar list yang memiliki nomor urut otomatis.
#
# 4. **Pembuatan Fungsi (Function)**
#    * Pendefinisian fungsi khusus bernama `perkenalan()` dengan struktur parameter dinamis.
#    * Fungsi ini dirancang untuk mengembalikan string terformat yang memisahkan informasi menggunakan karakter pipa (`|`).
#
# ## Status Eksekusi
# Seluruh baris kode di dalam notebook ini telah **berhasil dieksekusi (runtime sukses)** dengan output cetak yang sesuai di bawah sel kode.
